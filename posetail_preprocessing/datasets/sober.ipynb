# %%
import sleap_io as sio

# %%
data_path = '/groups/karashchuk/karashchuklab/animal-datasets/sober-zebrafinch/051325_1150-1153/set1_115033/Camera2/g26_051325_1150-1153_labels.v002_allsets.slp'
labels = sio.load_file(data_path)

# %%
labels
# Out:
# Labels(labeled_frames=175777, videos=19, skeletons=1, tracks=0, suggestions=484, sessions=0)

# %%
labels.skeletons
# Out:
# [Skeleton(nodes=["beakTopTip", "beakTopL", "beakTopR", "beakBotTip", "beakBotL", "beakBotR", "cheeckL", "cheeckR", "eyeL", "eyeR", "Hdstg"], edges=[(0, 2), (0, 1), (1, 8), (2, 9), (3, 5), (3, 4), (4, 8), (4, 6), (5, 7), (5, 9), (8, 6), (8, 10), (9, 7), (9, 10)])]

# %%
keypoints = ["beakTopTip", "beakTopL", "beakTopR", "beakBotTip", "beakBotL", "beakBotR", "cheeckL", "cheeckR", "eyeL", "eyeR", "Hdstg"]
edges = [(0, 2), (0, 1), (1, 8), (2, 9), (3, 5), (3, 4), (4, 8), (4, 6), (5, 7), (5, 9), (8, 6), (8, 10), (9, 7), (9, 10)]
 
scheme = []
for kpt1, kpt2 in edges: 
    scheme.append([keypoints[kpt1], keypoints[kpt2]])

print(scheme)
# Out:
# [['beakTopTip', 'beakTopR'], ['beakTopTip', 'beakTopL'], ['beakTopL', 'eyeL'], ['beakTopR', 'eyeR'], ['beakBotTip', 'beakBotR'], ['beakBotTip', 'beakBotL'], ['beakBotL', 'eyeL'], ['beakBotL', 'cheeckL'], ['beakBotR', 'cheeckR'], ['beakBotR', 'eyeR'], ['eyeL', 'cheeckL'], ['eyeL', 'Hdstg'], ['eyeR', 'cheeckR'], ['eyeR', 'Hdstg']]
